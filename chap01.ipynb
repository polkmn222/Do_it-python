# %%
a = [1, 3, 4]
if 3 in a:
  print('There is 3')
# Out:
# There is 3

# %%
print('Hello world')
# Out:
# Hello world

# %%
for i in range(1, 11):
    print(str(i) + '번째 인사')
# Out:
# 1번째 인사
# 2번째 인사
# 3번째 인사
# 4번째 인사
# 5번째 인사
# 6번째 인사
# 7번째 인사
# 8번째 인사
# 9번째 인사
# 10번째 인사
